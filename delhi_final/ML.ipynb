# %%
import pandas as pd

# %%
df=pd.read_csv('zone_lat_lon.csv')

# %%
df
# Out:
#      Unnamed: 0        lat        lon    zone
# 0             0  28.564017  77.210292  yellow
# 1             1  28.563917  77.216422     red
# 2             2  28.563816  77.222552   green
# 3             3  28.563716  77.228682   green
# 4             4  28.563615  77.234812     red
# ..          ...        ...        ...     ...
# 214         214  28.662289  77.221558  yellow
# 215         215  28.662188  77.227694  yellow
# 216         216  28.662087  77.233829   green
# 217         217  28.667126  77.212453   green
# 218         218  28.666824  77.230861   green
#
# [219 rows x 4 columns]

# %%
df=df.drop(['Unnamed: 0'],axis=1)

# %%
df
# Out:
#            lat        lon    zone
# 0    28.564017  77.210292  yellow
# 1    28.563917  77.216422     red
# 2    28.563816  77.222552   green
# 3    28.563716  77.228682   green
# 4    28.563615  77.234812     red
# ..         ...        ...     ...
# 214  28.662289  77.221558  yellow
# 215  28.662188  77.227694  yellow
# 216  28.662087  77.233829   green
# 217  28.667126  77.212453   green
# 218  28.666824  77.230861   green
#
# [219 rows x 3 columns]

# %%
x=df.drop(['zone'],axis=1).values
y=df['zone'].values

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42,test_size=0.15)

# %% [markdown]
# Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

lr=LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
lr.predict(x_test)
# Out:
# array(['green', 'green', 'green', 'green', 'green', 'green', 'green',
#        'green', 'green', 'green', 'green', 'green', 'green', 'green',
#        'green', 'green', 'green', 'green', 'green', 'green', 'green',
#        'green', 'green', 'green', 'green', 'green', 'green', 'green',
#        'green', 'green', 'green', 'green', 'green'], dtype=object)

# %%
y_test
# Out:
# array(['yellow', 'green', 'green', 'green', 'yellow', 'yellow', 'green',
#        'red', 'red', 'green', 'green', 'yellow', 'red', 'green', 'green',
#        'red', 'green', 'yellow', 'red', 'green', 'green', 'red', 'green',
#        'red', 'yellow', 'red', 'green', 'yellow', 'green', 'green',
#        'green', 'green', 'green'], dtype=object)

# %%
y_pred=lr.predict(x_test)

# %%
from sklearn.metrics import *
accuracy_score(y_test,y_pred)
# Out:
# 0.5454545454545454

# %%
df
# Out:
#            lat        lon    zone
# 0    28.564017  77.210292  yellow
# 1    28.563917  77.216422     red
# 2    28.563816  77.222552   green
# 3    28.563716  77.228682   green
# 4    28.563615  77.234812     red
# ..         ...        ...     ...
# 214  28.662289  77.221558  yellow
# 215  28.662188  77.227694  yellow
# 216  28.662087  77.233829   green
# 217  28.667126  77.212453   green
# 218  28.666824  77.230861   green
#
# [219 rows x 3 columns]

# %% [markdown]
# Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
rfc=RandomForestClassifier()
rfc.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred_rfc=rfc.predict(x_test)

# %%
accuracy_score(y_test,y_pred_rfc)
# Out:
# 0.5757575757575758

# %%
x
# Out:
# array([[28.56401659, 77.21029203],
#        [28.56391658, 77.21642204],
#        [28.56381629, 77.22255201],
#        [28.56371572, 77.22868195],
#        [28.56361488, 77.23481186],
#        [28.56351376, 77.24094174],
#        [28.56341237, 77.24707159],
#        [28.56885294, 77.20119454],
#        [28.56875333, 77.20732486],
#        [28.56865343, 77.21345515],
#        [28.56855327, 77.21958542],
#        [28.56845282, 77.22571565],
#        [28.5683521 , 77.23184584],
#        [28.5682511 , 77.23797601],
#        [28.56814982, 77.24410615],
#        [28.56804827, 77.25023625],
#        [28.56794644, 77.25636632],
#        [28.57368873, 77.19209619],
#        [28.57358951, 77.19822683],
#        [28.57349001, 77.20435744],
#        [28.57339024, 77.21048802],
#        [28.57329019, 77.21661856],
#        [28.57318986, 77.22274908],
#        [28.57308926, 77.22887957],
#        [28.57298838, 77.23501002],
#        [28.57288722, 77.24114044],
#        [28.57278579, 77.24727083],
# ...

# %% [markdown]
# input for test

# %%
lat_test=28.627864385
lon_test=77.2325217
rfc.predict([[lat_test,lon_test]])
# Out:
# array(['green'], dtype=object)

# %%
import folium
map_delhi = folium.Map(location=[lat_test, lon_test], zoom_start=13)
folium.Marker([lat_test, lon_test], popup='delhi').add_to(map_delhi)
for lat,lon,color in zip(df["lat"],df["lon"] ,df["zone"]):
   folium.Circle([lat, lon], radius=300, color=color, fill=True).add_to(map_delhi)
display(map_delhi)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
rfc.score(x_train,y_train)
# Out:
# 1.0

# %%
rfc.score(x_test,y_test)
# Out:
# 0.5757575757575758

# %%
confusion_matrix(y_test,y_pred_rfc)
# Out:
# array([[13,  2,  3],
#        [ 3,  4,  1],
#        [ 3,  2,  2]], dtype=int64)

# %%
print(classification_report(y_test,y_pred_rfc))
# Out:
#               precision    recall  f1-score   support
#
#        green       0.68      0.72      0.70        18
#          red       0.50      0.50      0.50         8
#       yellow       0.33      0.29      0.31         7
#
#     accuracy                           0.58        33
#    macro avg       0.51      0.50      0.50        33
# weighted avg       0.57      0.58      0.57        33

# %% [markdown]
# K Neighbors Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier
knc=KNeighborsClassifier()
knc.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred_knc=knc.predict(x_test)

# %%
accuracy_score(y_test,y_pred_knc)
# Out:
# 0.48484848484848486
